# %% [markdown]
# <p>
#   <center><img src="../assets/thakaa_logo.png" width="500" height="300"></center>
# </p>
#
# <p>
# <br>
#   <center><img src="../assets/artwork.png" width="600" height="300"></center>
# </p>
# <br>
# <h1 style='text-align: center;'>سلسلة معسكرات ذكاء: المعسكر الثالث | إطلاق و إدارة نماذج تعلم الآلة</h1>
# <!-- <font size="+2" style='text-align: center;'> تعلّم كيف تكتشف البيانات وتطوّر نماذج تعلّم الآلة </h2> -->
# <div style="text-align: center; font-family: Arial; font-size: 1.5em;">تعرّف على أحدث الأساليب والممارسات لنشر نماذج تعلّم الآلة وإطلاقها</div>

# %% [markdown]
# <h2 style="text-align: left;"> 📚 استيراد المكتبات</h2>

# %%
from pathlib import Path
import pandas as pd
import numpy as np

from pathlib import Path
from typing import List, Dict, Tuple

from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

import joblib

from sklearn.pipeline import Pipeline

# %% [markdown]
# <h2 style="text-align: left;">🚗 تحميل وتجهيز البيانات</h2>

# %%
data_folder_path = "../data/"
data_file_name = "UsedCarsSA_Unclean_EN.csv"
data_set_path = Path(data_folder_path, data_file_name)
df = pd.read_csv(data_set_path, delimiter=",", header=0, index_col=False, na_values="na", usecols=['Mileage', 'Year', 'Price'])
df = df[df['Price'] != 'Negotiable']
df['Price'] = df['Price'].apply(int)
df["class"] = df["Price"] > 50000
df.drop(columns="Price", inplace=True)
df["class"] = df["class"].replace([False,True],[0,1])

df.head()
# Out:
#    Year  Mileage  class
# 0  2018   103000      1
# 2  2019    72418      0
# 3  2019   114154      0
# 4  2019    41912      1
# 5  2018    39000      1

# %% [markdown]
# <h2 style="text-align: left;">🔪 تقسيم البيانات إلى جزء للتدريب وآخر للتقييم</h2>

# %%
train_test_split_frac = 0.8
random_seed_fix = 47
np.random.seed(random_seed_fix)
msk = np.random.rand(len(df)) < train_test_split_frac

df["flag_train"] = 0
df.loc[msk, "flag_train"] = 1

train_df = df[(df["flag_train"] == 1)].drop(["flag_train"], axis=1).copy()
test_df = df[(df["flag_train"] == 0)].drop(["flag_train"], axis=1).copy()

# %%
len(train_df)
# Out:
# 4473

# %%
len(test_df)
# Out:
# 1179

# %% [markdown]
# ## Scikit-learn Pipelines

# %% [markdown]
# ### Component#1: Data Imputation
#
# https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html

# %%
imputer = SimpleImputer(missing_values=np.NaN, strategy='median')

# %% [markdown]
# ### Component#2: Data Scalling
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html

# %%
scaler = MinMaxScaler()

# %% [markdown]
# ### Component#3: Calssifier
#
# https://scikit-learn.org/stable/supervised_learning.html#supervised-learning

# %%
classifier = DecisionTreeClassifier(max_depth=10, random_state=42)

# %% [markdown]
# ### Constructing and training the pipeline
#
# https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html
#
#
# *Hint: * ---

# %%
def train_pipeline(df):
    estimators = [("imputer", imputer), # None
                  ("scaler", scaler),
                  ("model", classifier)]

    pipeline = Pipeline(estimators)  # None
    feature_columns = df.columns.values[df.columns.values != "class"]
    pipeline.fit(df[feature_columns], df["class"])

    return pipeline, feature_columns

pipeline, feature_columns = train_pipeline(train_df)

# %% [markdown]
# ### Saving the pipeline

# %%
def save_pipeline(folder_path, pipeline, feature_columns):
    # Dump .... 
    # save the pipeline
    pipeline_name = "pipeline.pkl" # TODO: change it to .pkl
    pipeline_path = Path(folder_path, pipeline_name)
    ## Enter the line that dumps/saves the pipeline, hint:use the function joblib
    # Change it to pickle.
    
    # Write a command that saves the pipeline using joblib package
    # Hint: Look for the function "dump()"
    joblib.dump(pipeline, pipeline_path) # None

    # save the feature_columns
    cols_name = "pipeline_cols.pkl"
    cols_path = Path(folder_path, cols_name)
    joblib.dump(feature_columns, cols_path) # None
    
output_path = Path("../pipeline-output")
output_path.mkdir(parents=True, exist_ok=True)

save_pipeline(output_path, pipeline, feature_columns)

# %%
## TODO: Assertion command to check that the saving was done successuflly

# %% [markdown]
# ### Loading the pipeline

# %%
def load_pipeline(folder_path):
    # load the pipeline
    #### Write a line that loads the model ..
    model_name = "pipeline.pkl"
    model_path = Path(folder_path, model_name)
    model = joblib.load(model_path)

    # Write a command that loads the pipeline using joblib package
    # Hint: Look for the function "joblib.load()"
    # load the feature_columns
    cols_name = "pipeline_cols.pkl"
    cols_path = Path(folder_path, cols_name)
    feature_columns = joblib.load(cols_path)

    return pipeline, feature_columns

# Load the model, the scaler, the imputer and the names of the columns from files:
pipeline, feature_columns = load_pipeline(output_path)

# %%
## TODO: Assertion command to check that the saving was done successuflly

# %% [markdown]
# ### Do predictions using the trained pipeline

# %%
def predict_pipeline(test_df, pipeline, feature_columns):
    # Compute predictions using the trained pipeline
    # Write a line that predicts the y values for the test data using the pipeline
    # Hint: Look for method that predicts and use the feature_columns saved to restrict the used features.
    y_hat = pipeline.predict(test_df[feature_columns]) # None

    return y_hat

# Use the loaded model and other logic to get predictions for test-data in `test_df`:
pipeline_y_hat = predict_pipeline(test_df, pipeline, feature_columns)
pipeline_y_hat
# Out:
# array([0, 1, 1, ..., 1, 1, 0])

# %% [markdown]
# ## 5. ONNX (Extra)
#
# That was fun, but probably not that useful to any of you. However we added it to highlight two things. Firstly, the fact that you can move away from Python to deliver the model, while still developing it in Python. And secondly, or probably most imporantly, that the code and the weights are inextricably linked!
#
# So while that was one lesser used method, let's go through the most predominant method for making model artifacts from Python to any platform you want. This is ONNX - Open Neural Network eXchange, and as the name suggests it was developed as an open standard for sharing neural networks. However, it now supports traditional ML models, like the ones we have been making in this course.
#
# We will need to use the `skl2onnx` library. There are two ways to convert the model. A first method `convert_sklearn` which is a comprehensive way of converting. A second `to_onnx` which is calls `convert_sklearn`, but with simplified parameters and allows the option to infer the information from the training data. We won't show `to_onnx`, you can do that yourself.
#
# To start with we will use `convert_sklearn`, and as such we need to think about the datatype that we will be inputting. Lets have a look at what goes into the pipeline:

# %%
onnx_df = train_df.copy()

onnx_df[onnx_df.columns] = onnx_df[onnx_df.columns].apply(pd.to_numeric, errors='coerce')

onnx_feature_columns = onnx_df.columns.values[onnx_df.columns.values != "class"]

onnx_df.iloc[0].values
# Out:
# array([  2018, 103000,      1])

# %% [markdown]
# We can check the type using numpy's `dtype`:

# %%
onnx_df.iloc[0].values.dtype
# Out:
# dtype('int64')

# %%
print(onnx_df.iloc[0].shape)
# Out:
# (3,)

# %%
onnx_df
# Out:
#       Year  Mileage  class
# 0     2018   103000      1
# 3     2019   114154      0
# 4     2019    41912      1
# 5     2018    39000      1
# 6     2011   183000      1
# ...    ...      ...    ...
# 8240  2013   277000      0
# 8241  2012   147000      0
# 8242  2006   257000      0
# 8246  2011    18500      0
# 8247  2013   256000      0
#
# [4473 rows x 3 columns]

# %% [markdown]
# And will get it to be a `float64` type. Okay! We know enough to start up. Lets import the libraries we need.

# %%
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

# %% [markdown]
# The `initial_types` variable might take some getting used to. Assume that the specified scikit-learn model takes an input where the first 10 elements are floats and the last 100 elements are integers. For `convert_sklearn` we need to specify initial types. These mean importing `FloatTensorType` and `Int64TensorType` for the two different types:
#
# ```Python
# from skl2onnx.common.data_types import FloatTensorType, Int64TensorType
# ```
#
# We can then define the `initial_type` as a python list, where each element is a tuple of a variable name and a type
#
# ```Python
# initial_type = [('float_input', FloatTensorType([None, 10])),
#                 ('int64_input', Int64TensorType([None, 100]))]
# ```
#
# The `[None]` in `[None, 10]` indicates the batch size here is unknown. For our model it is super easy. The type is `Float` and they are all of that type, so its size is 170 (171 columns including the class).
#
# Lets convert the model now then:

# %%
initial_type = [('float_input', FloatTensorType([None, 2]))]

# Convert the model pipeline to ONNX. 
# The `pipeline` object is the same as before - so make sure you've run that code earlier in the notebook.
onnx = convert_sklearn(pipeline, initial_types=initial_type)

# %%
onnx.graph.node
# Out:
# [input: "float_input"
# output: "variable"
# name: "Imputer"
# op_type: "Imputer"
# attribute {
#   name: "imputed_value_floats"
#   floats: 2016.0
#   floats: 100000.0
#   type: FLOATS
# }
# attribute {
#   name: "replaced_value_float"
#   f: nan
#   type: FLOAT
# }
# domain: "ai.onnx.ml"
# , input: "variable"
# output: "Ca_output0"
# name: "Ca_Cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   i: 1
#   type: INT
# }
# domain: ""
# , input: "Ca_output0"
# input: "Mu_Mulcst"
# output: "Mu_C0"
# name: "Mu_Mul"
# op_type: "Mul"
# domain: ""
# , input: "Mu_C0"
# input: "Ad_Addcst"
# output: "variable1"
# name: "Ad_Add"
# op_type: "Add"
# domain: ""
# , input: "variable1"
# output: "label"
# output: "probabilities"
# name: "TreeEnsembleClassifier"
# op_type: "TreeEnsembleClassifier"
# attribute {
#   name: "class_ids"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "class_nodeids"
#   ints: 8
#   ints: 10
#   ints: 12
#   ints: 13
#   ints: 15
#   ints: 17
#   ints: 18
#   ints: 19
#   ints: 20
#   ints: 23
#   ints: 24
#   ints: 25
#   ints: 28
#   ints: 33
#   ints: 34
#   ints: 36
#   ints: 38
#   ints: 39
#   ints: 41
#   ints: 43
#   ints: 44
#   ints: 46
#   ints: 50
#   ints: 51
#   ints: 52
#   ints: 53
#   ints: 60
#   ints: 61
#   ints: 62
#   ints: 64
#   ints: 66
#   ints: 67
#   ints: 69
#   ints: 72
#   ints: 73
#   ints: 75
#   ints: 76
#   ints: 77
#   ints: 79
#   ints: 82
#   ints: 83
#   ints: 87
#   ints: 88
#   ints: 89
#   ints: 90
#   ints: 96
#   ints: 98
#   ints: 99
#   ints: 102
#   ints: 103
#   ints: 104
#   ints: 106
#   ints: 108
#   ints: 109
#   ints: 113
#   ints: 114
#   ints: 115
#   ints: 121
#   ints: 122
#   ints: 124
#   ints: 125
#   ints: 126
#   ints: 129
#   ints: 131
#   ints: 132
#   ints: 133
#   ints: 136
#   ints: 138
#   ints: 140
#   ints: 141
#   ints: 145
#   ints: 146
#   ints: 147
#   ints: 149
#   ints: 151
#   ints: 152
#   ints: 159
#   ints: 161
#   ints: 162
#   ints: 164
#   ints: 166
#   ints: 167
#   ints: 169
#   ints: 171
#   ints: 173
#   ints: 174
#   ints: 175
#   ints: 176
#   ints: 181
#   ints: 184
#   ints: 185
#   ints: 187
#   ints: 188
#   ints: 189
#   ints: 192
#   ints: 195
#   ints: 196
#   ints: 197
#   ints: 199
#   ints: 202
#   ints: 203
#   ints: 204
#   ints: 206
#   ints: 208
#   ints: 210
#   ints: 211
#   ints: 217
#   ints: 219
#   ints: 221
#   ints: 223
#   ints: 225
#   ints: 226
#   ints: 231
#   ints: 233
#   ints: 234
#   ints: 237
#   ints: 238
#   ints: 239
#   ints: 241
#   ints: 242
#   ints: 243
#   ints: 248
#   ints: 249
#   ints: 251
#   ints: 254
#   ints: 255
#   ints: 257
#   ints: 258
#   ints: 263
#   ints: 264
#   ints: 265
#   ints: 267
#   ints: 269
#   ints: 270
#   ints: 272
#   ints: 275
#   ints: 276
#   ints: 278
#   ints: 279
#   ints: 284
#   ints: 286
#   ints: 287
#   ints: 289
#   ints: 290
#   ints: 292
#   ints: 294
#   ints: 295
#   ints: 298
#   ints: 299
#   ints: 301
#   ints: 303
#   ints: 305
#   ints: 306
#   ints: 310
#   ints: 312
#   ints: 316
#   ints: 317
#   ints: 318
#   ints: 319
#   ints: 321
#   ints: 323
#   ints: 327
#   ints: 328
#   ints: 329
#   ints: 331
#   ints: 333
#   ints: 334
#   ints: 340
#   ints: 342
#   ints: 343
#   ints: 345
#   ints: 347
#   ints: 348
#   ints: 350
#   ints: 352
#   ints: 354
#   ints: 355
#   ints: 357
#   ints: 359
#   ints: 361
#   ints: 363
#   ints: 364
#   ints: 366
#   ints: 368
#   ints: 372
#   ints: 373
#   ints: 375
#   ints: 376
#   ints: 379
#   ints: 380
#   ints: 382
#   ints: 383
#   ints: 391
#   ints: 393
#   ints: 394
#   ints: 396
#   ints: 398
#   ints: 399
#   ints: 401
#   ints: 403
#   ints: 405
#   ints: 406
#   ints: 410
#   ints: 412
#   ints: 413
#   ints: 414
#   ints: 417
#   ints: 418
#   ints: 421
#   ints: 422
#   ints: 424
#   ints: 425
#   ints: 427
#   ints: 429
#   ints: 430
#   ints: 435
#   ints: 438
#   ints: 439
#   ints: 441
#   ints: 442
#   ints: 445
#   ints: 446
#   ints: 447
#   ints: 448
#   ints: 454
#   ints: 455
#   ints: 457
#   ints: 458
#   ints: 460
#   ints: 462
#   ints: 463
#   ints: 467
#   ints: 468
#   ints: 469
#   ints: 472
#   ints: 473
#   ints: 475
#   ints: 476
#   ints: 478
#   ints: 482
#   ints: 483
#   ints: 485
#   ints: 486
#   ints: 488
#   ints: 490
#   ints: 491
#   ints: 498
#   ints: 499
#   ints: 502
#   ints: 503
#   ints: 505
#   ints: 506
#   ints: 508
#   ints: 511
#   ints: 512
#   ints: 514
#   ints: 515
#   ints: 517
#   ints: 521
#   ints: 522
#   ints: 524
#   ints: 525
#   ints: 528
#   ints: 529
#   ints: 531
#   ints: 532
#   ints: 536
#   ints: 537
#   ints: 541
#   ints: 542
#   ints: 543
#   ints: 545
#   ints: 547
#   ints: 548
#   ints: 551
#   ints: 553
#   ints: 555
#   ints: 556
#   ints: 559
#   ints: 560
#   ints: 561
#   ints: 567
#   ints: 568
#   ints: 569
#   ints: 573
#   ints: 574
#   ints: 576
#   ints: 577
#   ints: 579
#   ints: 581
#   ints: 582
#   ints: 587
#   ints: 588
#   ints: 590
#   ints: 591
#   ints: 594
#   ints: 595
#   ints: 597
#   ints: 598
#   ints: 599
#   ints: 605
#   ints: 606
#   ints: 608
#   ints: 609
#   ints: 612
#   ints: 613
#   ints: 615
#   ints: 616
#   ints: 618
#   ints: 621
#   ints: 622
#   ints: 623
#   ints: 628
#   ints: 629
#   ints: 631
#   ints: 632
#   ints: 633
#   ints: 634
#   type: INTS
# }
# attribute {
#   name: "class_treeids"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "class_weights"
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.3333333432674408
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.095238097012043
#   floats: 0.5
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.25
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.04545454680919647
#   floats: 1.0
#   floats: 0.1764705926179886
#   floats: 1.0
#   floats: 0.25
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.09774436056613922
#   floats: 0.4000000059604645
#   floats: 1.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.5
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.3076923191547394
#   floats: 1.0
#   floats: 0.095238097012043
#   floats: 0.29411765933036804
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.5
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.5
#   floats: 0.0
#   floats: 1.0
#   floats: 0.5714285969734192
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.5
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.5
#   floats: 1.0
#   floats: 0.0
#   floats: 0.37837839126586914
#   floats: 1.0
#   floats: 0.0
#   floats: 0.2222222238779068
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.29629629850387573
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.6666666865348816
#   floats: 0.0
#   floats: 0.6666666865348816
#   floats: 0.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.6666666865348816
#   floats: 1.0
#   floats: 0.0
#   floats: 0.6000000238418579
#   floats: 1.0
#   floats: 0.5
#   floats: 0.0
#   floats: 1.0
#   floats: 0.3333333432674408
#   floats: 0.9523809552192688
#   floats: 1.0
#   floats: 0.4615384638309479
#   floats: 0.7272727489471436
#   floats: 0.0
#   floats: 0.5
#   floats: 0.0
#   floats: 0.5
#   floats: 0.0
#   floats: 1.0
#   floats: 0.6666666865348816
#   floats: 0.0
#   floats: 0.0
#   floats: 0.3333333432674408
#   floats: 0.6666666865348816
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.4848484992980957
#   floats: 0.6071428656578064
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.25
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.4285714328289032
#   floats: 0.20000000298023224
#   floats: 1.0
#   floats: 0.0
#   floats: 0.46666666865348816
#   floats: 1.0
#   floats: 0.0
#   floats: 0.8571428656578064
#   floats: 0.0
#   floats: 0.5
#   floats: 0.0
#   floats: 0.3333333432674408
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.3333333432674408
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.260869562625885
#   floats: 0.800000011920929
#   floats: 0.0
#   floats: 0.3333333432674408
#   floats: 0.6666666865348816
#   floats: 1.0
#   floats: 0.4166666567325592
#   floats: 0.0
#   floats: 1.0
#   floats: 0.25
#   floats: 0.6875
#   floats: 0.0
#   floats: 1.0
#   floats: 0.2666666805744171
#   floats: 1.0
#   floats: 0.0
#   floats: 0.8333333134651184
#   floats: 0.5925925970077515
#   floats: 0.0
#   floats: 1.0
#   floats: 0.5
#   floats: 0.0
#   floats: 0.0
#   floats: 0.3333333432674408
#   floats: 0.5
#   floats: 1.0
#   floats: 0.0
#   floats: 0.6666666865348816
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 1.0
#   floats: 0.5
#   floats: 0.0
#   floats: 0.75
#   floats: 0.0
#   floats: 0.3333333432674408
#   floats: 0.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 0.6000000238418579
#   floats: 0.3333333432674408
#   floats: 0.0
#   floats: 1.0
#   floats: 0.3333333432674408
#   floats: 1.0
#   floats: 0.8769230842590332
#   floats: 0.6800000071525574
#   floats: 0.0
#   floats: 0.8917197585105896
#   floats: 0.0
#   floats: 1.0
#   floats: 0.8999999761581421
#   floats: 0.0
#   floats: 0.9399999976158142
#   floats: 0.8048780560493469
#   floats: 0.8037974834442139
#   floats: 0.6538461446762085
#   floats: 1.0
#   floats: 0.0
#   floats: 0.6666666865348816
#   floats: 0.0
#   floats: 0.6666666865348816
#   floats: 0.7333333492279053
#   floats: 0.0
#   floats: 1.0
#   floats: 0.7596153616905212
#   floats: 0.0
#   floats: 0.0
#   floats: 0.5
#   floats: 0.6666666865348816
#   floats: 0.75
#   floats: 1.0
#   floats: 0.5
#   floats: 0.0
#   floats: 0.7311828136444092
#   floats: 0.9090909361839294
#   floats: 0.7777777910232544
#   floats: 0.9230769276618958
#   floats: 0.6388888955116272
#   floats: 0.8571428656578064
#   floats: 0.3333333432674408
#   floats: 0.0
#   floats: 1.0
#   floats: 0.800000011920929
#   floats: 1.0
#   floats: 0.0
#   floats: 0.644032895565033
#   floats: 0.7894737124443054
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.3636363744735718
#   floats: 1.0
#   floats: 0.3333333432674408
#   floats: 1.0
#   floats: 0.0
#   floats: 1.0
#   floats: 0.0
#   floats: 0.8235294222831726
#   floats: 0.5
#   floats: 0.875
#   floats: 1.0
#   floats: 0.0
#   floats: 0.7272727489471436
#   floats: 0.8695651888847351
#   floats: 0.5517241358757019
#   floats: 0.6666666865348816
#   floats: 0.0
#   floats: 0.4166666567325592
#   floats: 0.644444465637207
#   floats: 0.8666666746139526
#   floats: 0.3571428656578064
#   floats: 0.6176470518112183
#   floats: 1.0
#   floats: 0.6196721196174622
#   floats: 0.8055555820465088
#   floats: 0.5
#   floats: 0.6388888955116272
#   floats: 0.4554455578327179
#   floats: 0.125
#   floats: 1.0
#   floats: 0.5
#   floats: 1.0
#   floats: 0.75
#   floats: 0.3333333432674408
#   floats: 1.0
#   floats: 0.5
#   floats: 0.23076923191547394
#   floats: 1.0
#   floats: 0.75
#   floats: 0.0
#   floats: 1.0
#   type: FLOATS
# }
# attribute {
#   name: "classlabels_int64s"
#   ints: 0
#   ints: 1
#   type: INTS
# }
# attribute {
#   name: "nodes_falsenodeids"
#   ints: 212
#   ints: 91
#   ints: 26
#   ints: 21
#   ints: 20
#   ints: 19
#   ints: 14
#   ints: 9
#   ints: 0
#   ints: 11
#   ints: 0
#   ints: 13
#   ints: 0
#   ints: 0
#   ints: 16
#   ints: 0
#   ints: 18
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 25
#   ints: 24
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 54
#   ints: 29
#   ints: 0
#   ints: 45
#   ints: 40
#   ints: 35
#   ints: 34
#   ints: 0
#   ints: 0
#   ints: 37
#   ints: 0
#   ints: 39
#   ints: 0
#   ints: 0
#   ints: 42
#   ints: 0
#   ints: 44
#   ints: 0
#   ints: 0
#   ints: 47
#   ints: 0
#   ints: 53
#   ints: 52
#   ints: 51
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 78
#   ints: 77
#   ints: 68
#   ints: 63
#   ints: 62
#   ints: 61
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 65
#   ints: 0
#   ints: 67
#   ints: 0
#   ints: 0
#   ints: 70
#   ints: 0
#   ints: 74
#   ints: 73
#   ints: 0
#   ints: 0
#   ints: 76
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 80
#   ints: 0
#   ints: 84
#   ints: 83
#   ints: 0
#   ints: 0
#   ints: 90
#   ints: 89
#   ints: 88
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 153
#   ints: 110
#   ints: 105
#   ints: 100
#   ints: 97
#   ints: 0
#   ints: 99
#   ints: 0
#   ints: 0
#   ints: 104
#   ints: 103
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 107
#   ints: 0
#   ints: 109
#   ints: 0
#   ints: 0
#   ints: 116
#   ints: 115
#   ints: 114
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 134
#   ints: 127
#   ints: 126
#   ints: 123
#   ints: 122
#   ints: 0
#   ints: 0
#   ints: 125
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 133
#   ints: 130
#   ints: 0
#   ints: 132
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 142
#   ints: 137
#   ints: 0
#   ints: 139
#   ints: 0
#   ints: 141
#   ints: 0
#   ints: 0
#   ints: 148
#   ints: 147
#   ints: 146
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 150
#   ints: 0
#   ints: 152
#   ints: 0
#   ints: 0
#   ints: 177
#   ints: 176
#   ints: 175
#   ints: 168
#   ints: 163
#   ints: 160
#   ints: 0
#   ints: 162
#   ints: 0
#   ints: 0
#   ints: 165
#   ints: 0
#   ints: 167
#   ints: 0
#   ints: 0
#   ints: 170
#   ints: 0
#   ints: 172
#   ints: 0
#   ints: 174
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 205
#   ints: 190
#   ints: 189
#   ints: 182
#   ints: 0
#   ints: 186
#   ints: 185
#   ints: 0
#   ints: 0
#   ints: 188
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 198
#   ints: 193
#   ints: 0
#   ints: 197
#   ints: 196
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 200
#   ints: 0
#   ints: 204
#   ints: 203
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 207
#   ints: 0
#   ints: 209
#   ints: 0
#   ints: 211
#   ints: 0
#   ints: 0
#   ints: 384
#   ints: 307
#   ints: 244
#   ints: 227
#   ints: 218
#   ints: 0
#   ints: 220
#   ints: 0
#   ints: 222
#   ints: 0
#   ints: 224
#   ints: 0
#   ints: 226
#   ints: 0
#   ints: 0
#   ints: 243
#   ints: 240
#   ints: 235
#   ints: 232
#   ints: 0
#   ints: 234
#   ints: 0
#   ints: 0
#   ints: 239
#   ints: 238
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 242
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 280
#   ints: 259
#   ints: 250
#   ints: 249
#   ints: 0
#   ints: 0
#   ints: 252
#   ints: 0
#   ints: 256
#   ints: 255
#   ints: 0
#   ints: 0
#   ints: 258
#   ints: 0
#   ints: 0
#   ints: 271
#   ints: 266
#   ints: 265
#   ints: 264
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 268
#   ints: 0
#   ints: 270
#   ints: 0
#   ints: 0
#   ints: 273
#   ints: 0
#   ints: 277
#   ints: 276
#   ints: 0
#   ints: 0
#   ints: 279
#   ints: 0
#   ints: 0
#   ints: 296
#   ints: 291
#   ints: 288
#   ints: 285
#   ints: 0
#   ints: 287
#   ints: 0
#   ints: 0
#   ints: 290
#   ints: 0
#   ints: 0
#   ints: 293
#   ints: 0
#   ints: 295
#   ints: 0
#   ints: 0
#   ints: 300
#   ints: 299
#   ints: 0
#   ints: 0
#   ints: 302
#   ints: 0
#   ints: 304
#   ints: 0
#   ints: 306
#   ints: 0
#   ints: 0
#   ints: 335
#   ints: 320
#   ints: 311
#   ints: 0
#   ints: 313
#   ints: 0
#   ints: 319
#   ints: 318
#   ints: 317
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 322
#   ints: 0
#   ints: 324
#   ints: 0
#   ints: 330
#   ints: 329
#   ints: 328
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 332
#   ints: 0
#   ints: 334
#   ints: 0
#   ints: 0
#   ints: 365
#   ints: 356
#   ints: 349
#   ints: 344
#   ints: 341
#   ints: 0
#   ints: 343
#   ints: 0
#   ints: 0
#   ints: 346
#   ints: 0
#   ints: 348
#   ints: 0
#   ints: 0
#   ints: 351
#   ints: 0
#   ints: 353
#   ints: 0
#   ints: 355
#   ints: 0
#   ints: 0
#   ints: 358
#   ints: 0
#   ints: 360
#   ints: 0
#   ints: 362
#   ints: 0
#   ints: 364
#   ints: 0
#   ints: 0
#   ints: 367
#   ints: 0
#   ints: 369
#   ints: 0
#   ints: 377
#   ints: 374
#   ints: 373
#   ints: 0
#   ints: 0
#   ints: 376
#   ints: 0
#   ints: 0
#   ints: 381
#   ints: 380
#   ints: 0
#   ints: 0
#   ints: 383
#   ints: 0
#   ints: 0
#   ints: 492
#   ints: 431
#   ints: 426
#   ints: 407
#   ints: 400
#   ints: 395
#   ints: 392
#   ints: 0
#   ints: 394
#   ints: 0
#   ints: 0
#   ints: 397
#   ints: 0
#   ints: 399
#   ints: 0
#   ints: 0
#   ints: 402
#   ints: 0
#   ints: 404
#   ints: 0
#   ints: 406
#   ints: 0
#   ints: 0
#   ints: 415
#   ints: 414
#   ints: 411
#   ints: 0
#   ints: 413
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 419
#   ints: 418
#   ints: 0
#   ints: 0
#   ints: 423
#   ints: 422
#   ints: 0
#   ints: 0
#   ints: 425
#   ints: 0
#   ints: 0
#   ints: 428
#   ints: 0
#   ints: 430
#   ints: 0
#   ints: 0
#   ints: 449
#   ints: 448
#   ints: 443
#   ints: 436
#   ints: 0
#   ints: 440
#   ints: 439
#   ints: 0
#   ints: 0
#   ints: 442
#   ints: 0
#   ints: 0
#   ints: 447
#   ints: 446
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 477
#   ints: 464
#   ints: 459
#   ints: 456
#   ints: 455
#   ints: 0
#   ints: 0
#   ints: 458
#   ints: 0
#   ints: 0
#   ints: 461
#   ints: 0
#   ints: 463
#   ints: 0
#   ints: 0
#   ints: 470
#   ints: 469
#   ints: 468
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 474
#   ints: 473
#   ints: 0
#   ints: 0
#   ints: 476
#   ints: 0
#   ints: 0
#   ints: 479
#   ints: 0
#   ints: 487
#   ints: 484
#   ints: 483
#   ints: 0
#   ints: 0
#   ints: 486
#   ints: 0
#   ints: 0
#   ints: 489
#   ints: 0
#   ints: 491
#   ints: 0
#   ints: 0
#   ints: 562
#   ints: 533
#   ints: 516
#   ints: 507
#   ints: 500
#   ints: 499
#   ints: 0
#   ints: 0
#   ints: 504
#   ints: 503
#   ints: 0
#   ints: 0
#   ints: 506
#   ints: 0
#   ints: 0
#   ints: 509
#   ints: 0
#   ints: 513
#   ints: 512
#   ints: 0
#   ints: 0
#   ints: 515
#   ints: 0
#   ints: 0
#   ints: 518
#   ints: 0
#   ints: 526
#   ints: 523
#   ints: 522
#   ints: 0
#   ints: 0
#   ints: 525
#   ints: 0
#   ints: 0
#   ints: 530
#   ints: 529
#   ints: 0
#   ints: 0
#   ints: 532
#   ints: 0
#   ints: 0
#   ints: 549
#   ints: 538
#   ints: 537
#   ints: 0
#   ints: 0
#   ints: 544
#   ints: 543
#   ints: 542
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 546
#   ints: 0
#   ints: 548
#   ints: 0
#   ints: 0
#   ints: 557
#   ints: 552
#   ints: 0
#   ints: 554
#   ints: 0
#   ints: 556
#   ints: 0
#   ints: 0
#   ints: 561
#   ints: 560
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 600
#   ints: 583
#   ints: 570
#   ints: 569
#   ints: 568
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 578
#   ints: 575
#   ints: 574
#   ints: 0
#   ints: 0
#   ints: 577
#   ints: 0
#   ints: 0
#   ints: 580
#   ints: 0
#   ints: 582
#   ints: 0
#   ints: 0
#   ints: 599
#   ints: 592
#   ints: 589
#   ints: 588
#   ints: 0
#   ints: 0
#   ints: 591
#   ints: 0
#   ints: 0
#   ints: 596
#   ints: 595
#   ints: 0
#   ints: 0
#   ints: 598
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 624
#   ints: 617
#   ints: 610
#   ints: 607
#   ints: 606
#   ints: 0
#   ints: 0
#   ints: 609
#   ints: 0
#   ints: 0
#   ints: 614
#   ints: 613
#   ints: 0
#   ints: 0
#   ints: 616
#   ints: 0
#   ints: 0
#   ints: 619
#   ints: 0
#   ints: 623
#   ints: 622
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 634
#   ints: 633
#   ints: 630
#   ints: 629
#   ints: 0
#   ints: 0
#   ints: 632
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "nodes_featureids"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 1
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "nodes_hitrates"
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   floats: 1.0
#   type: FLOATS
# }
# attribute {
#   name: "nodes_missing_value_tracks_true"
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "nodes_modes"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "BRANCH_LEQ"
#   strings: "LEAF"
#   strings: "LEAF"
# ...
#   ints: 0
#   ints: 510
#   ints: 511
#   ints: 0
#   ints: 0
#   ints: 514
#   ints: 0
#   ints: 0
#   ints: 517
#   ints: 0
#   ints: 519
#   ints: 520
#   ints: 521
#   ints: 0
#   ints: 0
#   ints: 524
#   ints: 0
#   ints: 0
#   ints: 527
#   ints: 528
#   ints: 0
#   ints: 0
#   ints: 531
#   ints: 0
#   ints: 0
#   ints: 534
#   ints: 535
#   ints: 536
#   ints: 0
#   ints: 0
#   ints: 539
#   ints: 540
#   ints: 541
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 545
#   ints: 0
#   ints: 547
#   ints: 0
#   ints: 0
#   ints: 550
#   ints: 551
#   ints: 0
#   ints: 553
#   ints: 0
#   ints: 555
#   ints: 0
#   ints: 0
#   ints: 558
#   ints: 559
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 563
#   ints: 564
#   ints: 565
#   ints: 566
#   ints: 567
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 571
#   ints: 572
#   ints: 573
#   ints: 0
#   ints: 0
#   ints: 576
#   ints: 0
#   ints: 0
#   ints: 579
#   ints: 0
#   ints: 581
#   ints: 0
#   ints: 0
#   ints: 584
#   ints: 585
#   ints: 586
#   ints: 587
#   ints: 0
#   ints: 0
#   ints: 590
#   ints: 0
#   ints: 0
#   ints: 593
#   ints: 594
#   ints: 0
#   ints: 0
#   ints: 597
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 601
#   ints: 602
#   ints: 603
#   ints: 604
#   ints: 605
#   ints: 0
#   ints: 0
#   ints: 608
#   ints: 0
#   ints: 0
#   ints: 611
#   ints: 612
#   ints: 0
#   ints: 0
#   ints: 615
#   ints: 0
#   ints: 0
#   ints: 618
#   ints: 0
#   ints: 620
#   ints: 621
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 625
#   ints: 626
#   ints: 627
#   ints: 628
#   ints: 0
#   ints: 0
#   ints: 631
#   ints: 0
#   ints: 0
#   ints: 0
#   ints: 0
#   type: INTS
# }
# attribute {
#   name: "nodes_values"
#   floats: 0.8534482717514038
#   floats: 0.8017241358757019
#   floats: 0.5086206793785095
#   floats: 0.02220049314200878
#   floats: 0.016200359910726547
#   floats: 0.4913792908191681
#   floats: 0.0036223027855157852
#   floats: 0.3534482717514038
#   floats: 0.0
#   floats: 0.37068963050842285
#   floats: 0.0
#   floats: 0.0005610124208033085
#   floats: 0.0
#   floats: 0.0
#   floats: 0.29310342669487
#   floats: 0.0
#   floats: 0.011200249195098877
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.04231204837560654
#   floats: 0.040200892835855484
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.7327585816383362
#   floats: 0.007700171321630478
#   floats: 0.0
#   floats: 0.03942309692502022
#   floats: 0.03353407606482506
#   floats: 0.0090890908613801
#   floats: 0.6982758045196533
#   floats: 0.0
#   floats: 0.0
#   floats: 0.027533944696187973
#   floats: 0.0
#   floats: 0.02920064888894558
#   floats: 0.0
#   floats: 0.0
#   floats: 0.03497855365276337
#   floats: 0.0
#   floats: 0.037534166127443314
#   floats: 0.0
#   floats: 0.0
#   floats: 0.6810344457626343
#   floats: 0.0
#   floats: 0.7155172228813171
#   floats: 0.09886886179447174
#   floats: 0.09609102457761765
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.047867730259895325
#   floats: 0.04720104858279228
#   floats: 0.003944532014429569
#   floats: 3.100068715866655e-05
#   floats: 3.0778461223235354e-05
#   floats: 2.2111602447694167e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 4.8445519496453926e-05
#   floats: 0.0
#   floats: 4.933443051413633e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 0.004533433821052313
#   floats: 0.0
#   floats: 0.0388675294816494
#   floats: 0.03831196203827858
#   floats: 0.0
#   floats: 0.0
#   floats: 0.767241358757019
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.05209004506468773
#   floats: 0.0
#   floats: 0.052312273532152176
#   floats: 0.767241358757019
#   floats: 0.0
#   floats: 0.0
#   floats: 0.10864685475826263
#   floats: 0.10620235651731491
#   floats: 0.10275783389806747
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.8362069129943848
#   floats: 0.007644614204764366
#   floats: 2.700060031202156e-05
#   floats: 0.818965494632721
#   floats: 1.966710260603577e-05
#   floats: 0.0
#   floats: 2.2778283891966566e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 1.6555923139094375e-05
#   floats: 4.777883532369742e-06
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 7.04460107954219e-05
#   floats: 0.0
#   floats: 7.566834392491728e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0159781314432621
#   floats: 0.00953354500234127
#   floats: 0.007977955043315887
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.07375719398260117
#   floats: 0.06275694817304611
#   floats: 0.06253471970558167
#   floats: 0.046978820115327835
#   floats: 0.04597879946231842
#   floats: 0.0
#   floats: 0.0
#   floats: 0.057534608989953995
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.818965494632721
#   floats: 0.06775706261396408
#   floats: 0.0
#   floats: 0.06964599341154099
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.08053512126207352
#   floats: 0.07427098602056503
#   floats: 0.0
#   floats: 0.07438209652900696
#   floats: 0.0
#   floats: 0.07453498989343643
#   floats: 0.0
#   floats: 0.0
#   floats: 0.818965494632721
#   floats: 0.08437276631593704
#   floats: 0.08270605653524399
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.08897975087165833
#   floats: 0.0
#   floats: 0.0958687961101532
#   floats: 0.0
#   floats: 0.0
#   floats: 0.014441764913499355
#   floats: 0.012311384081840515
#   floats: 0.009422430768609047
#   floats: 5.411231177276932e-05
#   floats: 4.233427171129733e-05
#   floats: 5.555679081226117e-07
#   floats: 0.0
#   floats: 1.7889286027639173e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 4.6001023292774335e-05
#   floats: 0.0
#   floats: 4.9889997171703726e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0004455654416233301
#   floats: 0.0
#   floats: 0.0018922642339020967
#   floats: 0.0
#   floats: 0.0038667526096105576
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0888686403632164
#   floats: 0.04575657099485397
#   floats: 0.04453432187438011
#   floats: 0.01811995729804039
#   floats: 0.0
#   floats: 0.019112979993224144
#   floats: 0.018997643142938614
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02062067948281765
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.06253471970558167
#   floats: 0.04953443259000778
#   floats: 0.0
#   floats: 0.05831240490078926
#   floats: 0.05742349475622177
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0640823096036911
#   floats: 0.0
#   floats: 0.08609079569578171
#   floats: 0.08453521132469177
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.09364651888608932
#   floats: 0.0
#   floats: 0.09786883741617203
#   floats: 0.0
#   floats: 0.09997999668121338
#   floats: 0.0
#   floats: 0.0
#   floats: 0.8879310488700867
#   floats: 0.03909231349825859
#   floats: 3.955643478548154e-05
#   floats: 1.4111424206930678e-05
#   floats: 4.888997409580043e-06
#   floats: 0.0
#   floats: 7.777950486342888e-06
#   floats: 0.0
#   floats: 1.1666925274766982e-05
#   floats: 0.0
#   floats: 1.2889175195596181e-05
#   floats: 0.0
#   floats: 1.322251591773238e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 3.233405004721135e-05
#   floats: 2.8778416890418157e-05
#   floats: 0.8706896305084229
#   floats: 1.7889286027639173e-05
#   floats: 0.0
#   floats: 2.3778306058375165e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 1.6333695384673774e-05
#   floats: 1.5222560250549577e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.8706896305084229
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02547367662191391
#   floats: 0.003609191160649061
#   floats: 4.288984200684354e-05
#   floats: 0.8706896305084229
#   floats: 0.0
#   floats: 0.0
#   floats: 4.4223204895388335e-05
#   floats: 0.0
#   floats: 4.822329356102273e-05
#   floats: 0.8706896305084229
#   floats: 0.0
#   floats: 0.0
#   floats: 7.14460329618305e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 0.8706896305084229
#   floats: 0.009866885840892792
#   floats: 0.007589057553559542
#   floats: 0.00454454543069005
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.018755972385406494
#   floats: 0.0
#   floats: 0.020311562344431877
#   floats: 0.0
#   floats: 0.0
#   floats: 0.014111424796283245
#   floats: 0.0
#   floats: 0.02406720072031021
#   floats: 0.018533743917942047
#   floats: 0.0
#   floats: 0.0
#   floats: 0.024644991382956505
#   floats: 0.0
#   floats: 0.0
#   floats: 0.026756148785352707
#   floats: 0.02631169557571411
#   floats: 0.026089467108249664
#   floats: 0.025695903226733208
#   floats: 0.0
#   floats: 0.025867240503430367
#   floats: 0.0
#   floats: 0.0
#   floats: 0.8706896305084229
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02653392218053341
#   floats: 0.0
#   floats: 0.8706896305084229
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02702893316745758
#   floats: 0.8706896305084229
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02742283046245575
#   floats: 0.0
#   floats: 0.027978399768471718
#   floats: 0.0
#   floats: 0.03275628387928009
#   floats: 0.0
#   floats: 0.0
#   floats: 0.8706896305084229
#   floats: 0.04420097917318344
#   floats: 0.04031200706958771
#   floats: 0.0
#   floats: 0.04064534604549408
#   floats: 0.0
#   floats: 0.04331207275390625
#   floats: 0.04297873377799988
#   floats: 0.0412009134888649
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.044456541538238525
#   floats: 0.0
#   floats: 0.04564545676112175
#   floats: 0.0
#   floats: 0.04711849242448807
#   floats: 0.04640780761837959
#   floats: 0.04597879946231842
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.04818340390920639
#   floats: 0.0
#   floats: 0.10321340709924698
#   floats: 0.0
#   floats: 0.0
#   floats: 0.047534387558698654
#   floats: 0.04469221457839012
#   floats: 0.044223204255104065
#   floats: 0.04178503900766373
#   floats: 0.03961798921227455
#   floats: 0.0
#   floats: 0.039729103446006775
#   floats: 0.0
#   floats: 0.0
#   floats: 0.042312052100896835
#   floats: 0.0
#   floats: 0.042534276843070984
#   floats: 0.0
#   floats: 0.0
#   floats: 0.04433431848883629
#   floats: 0.0
#   floats: 0.04446209594607353
#   floats: 0.0
#   floats: 0.044573210179805756
#   floats: 0.0
#   floats: 0.0
#   floats: 0.04501555487513542
#   floats: 0.0
#   floats: 0.0453006736934185
#   floats: 0.0
#   floats: 0.0465899221599102
#   floats: 0.0
#   floats: 0.047128159552812576
#   floats: 0.0
#   floats: 0.0
#   floats: 0.04853441193699837
#   floats: 0.0
#   floats: 0.049312204122543335
#   floats: 0.0
#   floats: 0.06753483414649963
#   floats: 0.06019500270485878
#   floats: 0.05864574760198593
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0643017590045929
#   floats: 0.0
#   floats: 0.0
#   floats: 0.07409053295850754
#   floats: 0.07186826318502426
#   floats: 0.0
#   floats: 0.0
#   floats: 0.11586546152830124
#   floats: 0.0
#   floats: 0.0
#   floats: 0.00996466539800167
#   floats: 0.9224137663841248
#   floats: 0.008311295881867409
#   floats: 0.0035889686550945044
#   floats: 2.2111602447694167e-05
#   floats: 1.0889130862778984e-05
#   floats: 2.000044332817197e-06
#   floats: 0.0
#   floats: 3.888975243171444e-06
#   floats: 0.0
#   floats: 0.0
#   floats: 1.344474276265828e-05
#   floats: 0.0
#   floats: 1.5000332496128976e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 2.566723560448736e-05
#   floats: 0.0
#   floats: 2.655614480318036e-05
#   floats: 0.0
#   floats: 3.955643478548154e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 0.9051724076271057
#   floats: 0.006195248570293188
#   floats: 0.004311206750571728
#   floats: 0.0
#   floats: 0.004755661357194185
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.004088979680091143
#   floats: 0.0038667526096105576
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0062445830553770065
#   floats: 0.005311228800565004
#   floats: 0.0
#   floats: 0.0
#   floats: 0.007334829308092594
#   floats: 0.0
#   floats: 0.0
#   floats: 0.00935798604041338
#   floats: 0.0
#   floats: 0.009580212645232677
#   floats: 0.0
#   floats: 0.0
#   floats: 1.955598963832017e-05
#   floats: 0.9741379022598267
#   floats: 0.9568965435028076
#   floats: 8.889086302588112e-07
#   floats: 0.0
#   floats: 6.77792831993429e-06
#   floats: 6.0001334531989414e-06
#   floats: 0.0
#   floats: 0.0
#   floats: 1.6222582416958176e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 4.666770109906793e-06
#   floats: 7.777950372656051e-07
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0049612210132181644
#   floats: 0.9396551847457886
#   floats: 0.0029445099644362926
#   floats: 0.002088935114443302
#   floats: 3.066734643653035e-05
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0027000599075108767
#   floats: 0.0
#   floats: 0.0
#   floats: 0.004200093448162079
#   floats: 0.0
#   floats: 0.004450987558811903
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0019111535511910915
#   floats: 0.0018555967835709453
#   floats: 0.0013944754609838128
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.00436865258961916
#   floats: 0.004357540979981422
#   floats: 0.0
#   floats: 0.0
#   floats: 0.004637769423425198
#   floats: 0.0
#   floats: 0.0
#   floats: 0.00502677820622921
#   floats: 0.0
#   floats: 0.9913793206214905
#   floats: 0.9568965435028076
#   floats: 0.007875730283558369
#   floats: 0.0
#   floats: 0.0
#   floats: 0.009301540441811085
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0052001154981553555
#   floats: 0.0
#   floats: 0.006049023475497961
#   floats: 0.0
#   floats: 0.0
#   floats: 0.9224137663841248
#   floats: 0.0283672958612442
#   floats: 0.020283449441194534
#   floats: 0.019609879702329636
#   floats: 0.01008911244571209
#   floats: 0.9051724076271057
#   floats: 0.0
#   floats: 0.0
#   floats: 0.01531922910362482
#   floats: 0.015289228409528732
#   floats: 0.0
#   floats: 0.0
#   floats: 0.015683235600590706
#   floats: 0.0
#   floats: 0.0
#   floats: 0.019683770835399628
#   floats: 0.0
#   floats: 0.9051724076271057
#   floats: 0.019867107272148132
#   floats: 0.0
#   floats: 0.0
#   floats: 0.019814996048808098
#   floats: 0.0
#   floats: 0.0
#   floats: 0.020537566393613815
#   floats: 0.0
#   floats: 0.9051724076271057
#   floats: 0.02080823853611946
#   floats: 0.020697126165032387
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02720060385763645
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02464699186384678
#   floats: 0.022256050258874893
#   floats: 0.0
#   floats: 0.0
#   floats: 0.026511700823903084
#   floats: 0.0
#   floats: 0.0
#   floats: 0.07452898472547531
#   floats: 0.028531411662697792
#   floats: 0.028459854423999786
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02875363826751709
#   floats: 0.02868463657796383
#   floats: 0.028605524450540543
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.028811750933527946
#   floats: 0.0
#   floats: 0.0659792423248291
#   floats: 0.0
#   floats: 0.0
#   floats: 0.9051724076271057
#   floats: 0.07664614915847778
#   floats: 0.0
#   floats: 0.07875730097293854
#   floats: 0.0
#   floats: 0.07997233420610428
#   floats: 0.0
#   floats: 0.0
#   floats: 0.07920175790786743
#   floats: 0.07753505557775497
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.01839051954448223
#   floats: 0.9568965435028076
#   floats: 0.010130224749445915
#   floats: 0.010019111447036266
#   floats: 0.9396551847457886
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.012244493700563908
#   floats: 0.011570146307349205
#   floats: 0.011166914366185665
#   floats: 0.0
#   floats: 0.0
#   floats: 0.011772039346396923
#   floats: 0.0
#   floats: 0.0
#   floats: 0.012410609051585197
#   floats: 0.0
#   floats: 0.01780306175351143
#   floats: 0.0
#   floats: 0.0
#   floats: 0.017867062240839005
#   floats: 0.013289183378219604
#   floats: 0.01248205453157425
#   floats: 0.012032933533191681
#   floats: 0.0
#   floats: 0.0
#   floats: 0.01275583915412426
#   floats: 0.0
#   floats: 0.0
#   floats: 0.01574590429663658
#   floats: 0.01484433002769947
#   floats: 0.0
#   floats: 0.0
#   floats: 0.016245471313595772
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.04530733823776245
#   floats: 0.04164537042379379
#   floats: 0.9568965435028076
#   floats: 0.028756193816661835
#   floats: 0.027729282155632973
#   floats: 0.0
#   floats: 0.0
#   floats: 0.03808973357081413
#   floats: 0.0
#   floats: 0.0
#   floats: 0.02745516411960125
#   floats: 0.025224005803465843
#   floats: 0.0
#   floats: 0.0
#   floats: 0.03231271728873253
#   floats: 0.0
#   floats: 0.0
#   floats: 0.044089868664741516
#   floats: 0.0
#   floats: 0.04497399926185608
#   floats: 0.9396551847457886
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.08486855030059814
#   floats: 0.06230315938591957
#   floats: 0.05546901002526283
#   floats: 0.049867771565914154
#   floats: 0.0
#   floats: 0.0
#   floats: 0.05742805451154709
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   floats: 0.0
#   type: FLOATS
# }
# attribute {
#   name: "post_transform"
#   s: "NONE"
#   type: STRING
# }
# domain: "ai.onnx.ml"
# , input: "probabilities"
# output: "output_probability"
# name: "ZipMap"
# op_type: "ZipMap"
# attribute {
#   name: "classlabels_int64s"
#   ints: 0
#   ints: 1
#   type: INTS
# }
# domain: "ai.onnx.ml"
# , input: "label"
# output: "output_label"
# name: "Cast"
# op_type: "Cast"
# attribute {
#   name: "to"
#   i: 7
#   type: INT
# }
# domain: ""
# ]

# %%
# Print only the first few characters, since the output is really long..
print(str(onnx)[:500])
# Out:
# ir_version: 8
# producer_name: "skl2onnx"
# producer_version: "1.13"
# domain: "ai.onnx"
# model_version: 0
# doc_string: ""
# graph {
#   node {
#     input: "float_input"
#     output: "variable"
#     name: "Imputer"
#     op_type: "Imputer"
#     attribute {
#       name: "imputed_value_floats"
#       floats: 2016.0
#       floats: 100000.0
#       type: FLOATS
#     }
#     attribute {
#       name: "replaced_value_float"
#       f: nan
#       type: FLOAT
#     }
#     domain: "ai.onnx.ml"
#   }
#   node {
#     input: "variable"
#     outpu

# %% [markdown]
# Have a look above and see the model format. Its kind of readible. You can also plot it as a graph!

# %%
from onnx.tools.net_drawer import GetPydotGraph, GetOpNodeProducer
import os
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
pydot_graph = GetPydotGraph(onnx.graph,
                            name=onnx.graph.name,
                            rankdir="TB",
                            node_producer=GetOpNodeProducer(
                                "docstring", color="yellow",
                                fillcolor="yellow", style="filled"))

pydot_graph.write_dot("pipeline_onnx.dot")

os.system('dot -O -Gdpi=300 -Tpng pipeline_onnx.dot')
# Out:
# 0

# %%
image = plt.imread("pipeline_onnx.dot.png")
fig, ax = plt.subplots(figsize=(40, 20))
ax.imshow(image)
ax.axis('off')
plt.show()

# %% [markdown]
# So that was a soft introduction into saving the pipeline/model in the ONNX-format. Now we just use the `.SerializeToString()` method to write the ONNX object to file. Lets write that up in a function:

# %%
def save_onnx(folder_path, pipeline, feature_columns):
    # convert to onnx
    initial_type = [('float_input', FloatTensorType([None, 2]))]
    onnx = convert_sklearn(pipeline, initial_types=initial_type)

    # save the pipeline
    pipeline_name = "pipeline.onnx"
    folder_path = Path(folder_path)
    folder_path.mkdir(parents=True, exist_ok=True)
    pipeline_path = Path(folder_path, pipeline_name)

    with open(pipeline_path, "wb") as f:
        f.write(onnx.SerializeToString())

    # save the feature_columns
    cols_name = "pipeline_cols.joblib"
    cols_path = Path(folder_path, cols_name)
    joblib.dump(feature_columns, cols_path)

# %%
save_onnx("onnx-output", pipeline, feature_columns)

# %% [markdown]
# Check out the results in the "onnx-output" folder!

# %% [markdown]
# Next up we need to examine how to consume ONNX and make predictions. This is where ONNX comes into its own. There are a tonne of ways of doing this for a multitude of platforms and programs. We will look at a server-based inference with a sample REST server, using `onnxruntime`.
#
# Lets define a load function that will load the runtime session and also the feature columns.

# %%
import onnxruntime as rt

# %%
def load_onnx(folder_path):
    # load the session
    pipeline_name = "pipeline.onnx"
    pipeline_path = Path(folder_path, pipeline_name)
    sess = rt.InferenceSession(str(pipeline_path))

    # load the feature_columns
    cols_name = "pipeline_cols.joblib"
    cols_path = Path(folder_path, cols_name)
    feature_columns = joblib.load(cols_path)

    return sess, feature_columns

# %%
# Load the ONNX model and the feature-columns using the function we just wrote:
sess, feature_columns = load_onnx("onnx-output")

# %% [markdown]
# We can look at the input and output names, types expected and shapes.

# %%
print("In", [(i.name, i.type, i.shape) for i in sess.get_inputs()])
print("Out", [(i.name, i.type, i.shape) for i in sess.get_outputs()])
# Out:
# In [('float_input', 'tensor(float)', [None, 2])]
# Out [('output_label', 'tensor(int64)', [None]), ('output_probability', 'seq(map(int64,tensor(float)))', [])]

# %% [markdown]
# Here we see that we have a input called `float_input` (remember we defined this above), and its a tensor type `float`. Its expected size is any number of samples in the batch, but exactly two columns.
#
# The output is called `output_label` (we could also get a probability too) which is the same as what we saw on the graph of the model. Its an tensor of `int64` output, but in a list.
#
# Lets write a function that does the predict, when given an dataframe as input, along with the session and columns.

# %%
def predict_pipeline(test_df, sess, feature_columns):

    sample_to_score = test_df[feature_columns].values.astype("float32")
    y_hat = sess.run(['output_label'], {'float_input': sample_to_score})

    return y_hat

# %% [markdown]
# We can make a prediciton of the test dataframe, and see what the output looks like

# %%
onnx_y_hat = predict_pipeline(test_df, sess, feature_columns)
onnx_y_hat
# Out:
# [array([0, 1, 1, ..., 1, 1, 0], dtype=int64)]

# %% [markdown]
# ## APIs

# %%
## TODO: Magic command to overwrite the cell

# %%
# %%writefile ../app.py

from fastapi import FastAPI
from typing import Optional
import glob
import os.path
import numpy as np
import pandas as pd
import pickle
import toml
from sklearn.preprocessing import OneHotEncoder
from pydantic import BaseModel,confloat

from pathlib import Path
from typing import List, Dict, Tuple

import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier

import joblib

from sklearn.pipeline import Pipeline

def load_pipeline(folder_path):
    # load the pipeline
    #### Write a line that loads the model ..
    model_name = "pipeline.pkl"
    model_path = Path(folder_path, model_name)
    model = joblib.load(model_path)

    # load the feature_columns
    cols_name = "pipeline_cols.pkl"
    cols_path = Path(folder_path, cols_name)
    feature_columns = joblib.load(cols_path)

    return model, feature_columns

app = FastAPI()

class Car(BaseModel):
    year: Optional[float]=2015
    mileage: Optional[float]=77000

    class Config:
        schema_extra = {
            "record": {'year':2015,
                       'mileage':77000,
                      }
        }
        
@app.on_event("startup")
def load_model():
    global pipeline
    global feature_columns

    output_path = Path("pipeline-output")
    pipeline, feature_columns = load_pipeline(output_path)
    
@app.get('/')
def index():
    return {"status": "pass"}


@app.post('/predict')
def get_price_classificatoon(data: Car):
    recieved = data
    print(data)
    year = recieved.year
    mileage = recieved.mileage
    X = np.array([year, mileage]).reshape(1, -1)
    pred_class = pipeline.predict(X)
    pred_proba = pipeline.predict_proba(X)
    if(pred_class==0):
        return {"Class":"Car Price <50k SAR","Probability":round(float(pred_proba[0][0]),3)}
    else:
        return {"Class":"Car Price >=50k SAR","Probability":round(float(pred_proba[0][1]),3)}
# Out:
# Writing app.py

# %%
## Make of the tasks solved, and if the time runs out, we can solve it for them.

# %%
! curl -X 'POST' \
  'http://127.0.0.1:8000/predict' \
  -H 'accept: application/json' \
  -H 'Content-Type: application/json' \
  -d '{ \
  "year": 1980, \
  "mileage": 200000 \
  }'
# Out:
# {"Class":"Car Price <50k SAR","Probability":0.904}

# %% [markdown]
# Show examples

# %%
! curl -X 'POST' \
  'http://127.0.0.1:8000/predict' \
  -H 'accept: application/json' \
  -H 'Content-Type: application/json' \
  -d '{ \
  "year": 1980, \
  "mileage": "dkmd" \
  }'
# Out:
# {"detail":[{"loc":["body","mileage"],"msg":"value is not a valid float","type":"type_error.float"}]}

# %%
! curl -X 'POST' \
  'http://127.0.0.1:8000/predict' \
  -H 'accept: application/json' \
  -H 'Content-Type: application/json' \
  -d '{ \
  "year": 2008 \
  }'
# Out:
# {"Class":"Car Price <50k SAR","Probability":0.77}

# %%
! curl -X 'POST' \
  'http://127.0.0.1:8000/predict' \
  -H 'accept: application/json' \
  -H 'Content-Type: application/json' \
  -d '{ \
  "year": 2008, \
  "mileage": 77000 \
  }'
# Out:
# {"Class":"Car Price <50k SAR","Probability":0.77}
